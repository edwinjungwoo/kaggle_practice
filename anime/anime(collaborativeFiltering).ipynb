# %% [markdown]
# # Anime dataset 불러오기
# * anime.csv : 애니메이션의 title, genre 등 item에 대한 info가 담긴 data
# * ratings.csv : 사용자(user)가 애니메이션(item)에 대한 rating이 담긴 data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b142dacc-5161-4e9d-bb7b-fc65b08b3fe4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b142dacc-5161-4e9d-bb7b-fc65b08b3fe4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving anime.csv to anime.csv
# Saving rating.csv to rating.csv

# %%
import pandas as pd
import numpy as np
import scipy as sp
from sklearn.metrics.pairwise import cosine_similarity
import operator
# %matplotlib inline

# %% [markdown]
# # Data Preprocessing (데이터 전처리)
# * dataset 구조 파악
# * 두 데이터셋을 하나로 병합
# * pivot table 생성

# %%
# 데이터프레임 형태로 할당
anime = pd.read_csv('anime.csv')
rating = pd.read_csv('rating.csv')

# %%
# anime column 확인
anime.head(3)
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
#
#    members
# 0   200630
# 1   793665
# 2   114262

# %%
# TV 방영 애니메이션만 추출
anime_tv = anime[anime['type']=='TV']    
anime_tv.head()
# Out:
#    anime_id                                               name  \
# 1      5114                   Fullmetal Alchemist: Brotherhood
# 2     28977                                           Gintama°
# 3      9253                                        Steins;Gate
# 4      9969                                      Gintama&#039;
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
#
#                                                genre type episodes  rating  \
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...   TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...   TV       51    9.25
# 3                                   Sci-Fi, Thriller   TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...   TV       51    9.16
# 5             Comedy, Drama, School, Shounen, Sports   TV       10    9.15
#
#    members
# 1   793665
# 2   114262
# 3   673572
# 4   151266
# 5    93351

# %%
# TV 방영 애니메이션 평가 수 파악
anime_tv.members.describe()
# Out:
# count    3.787000e+03
# mean     4.268366e+04
# std      8.912101e+04
# min      1.200000e+01
# 25%      4.830000e+02
# 50%      5.947000e+03
# 75%      4.424600e+04
# max      1.013917e+06
# Name: members, dtype: float64

# %%
# 평가 수 기준 상위 50% TV 애니메이션만 추출
anime_tv = anime_tv[anime_tv.members >= 5947]    
anime_tv.shape
# Out:
# (1894, 7)

# %%
# rating column 확인
rating.head(3)
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1

# %%
# -1로 표기된 평점을 NaN로 변환
rating.replace({-1: np.nan}, regex = True, inplace = True)    
rating.head(3)
# Out:
#    user_id  anime_id  rating
# 0        1        20     NaN
# 1        1        24     NaN
# 2        1        79     NaN

# %%
# anime data와 rating data 병합 (anime_id 기준)
merged = rating.merge(anime_tv, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])
merged.rename(columns = {'rating_user':'user_rating'}, inplace = True)

merged = merged[['user_id', 'name', 'user_rating']]    # 필요 column만

# %%
# 20000명에 대한 dataset (computing issue)
merged_sub = merged[merged.user_id <= 20000]

# %%
merged_sub.head()
# Out:
#    user_id    name  user_rating
# 0        1  Naruto          NaN
# 1        3  Naruto          8.0
# 2        5  Naruto          6.0
# 3        6  Naruto          NaN
# 4       10  Naruto          NaN

# %%
# 피봇 테이블 생성
piv = merged_sub.pivot_table(index = ['user_id'], columns = ['name'], values = 'user_rating')
print(piv.shape)
piv.head()
# Out:
# (18716, 1795)
# name     .hack//Roots  .hack//Sign  .hack//Tasogare no Udewa Densetsu  009-1  \
# user_id
# 1                 NaN          NaN                                NaN    NaN
# 2                 NaN          NaN                                NaN    NaN
# 3                 NaN          NaN                                NaN    NaN
# 5                 NaN          NaN                                NaN    NaN
# 7                 NaN          NaN                                NaN    NaN
#
# name     07-Ghost  11eyes  12-sai.: Chicchana Mune no Tokimeki  \
# user_id
# 1             NaN     NaN                                  NaN
# 2             NaN     NaN                                  NaN
# 3             NaN     NaN                                  NaN
# 5             NaN     NaN                                  NaN
# 7             NaN     NaN                                  NaN
#
# name     30-sai no Hoken Taiiku  91 Days  A-Channel  ...  \
# user_id                                              ...
# 1                           NaN      NaN        NaN  ...
# 2                           NaN      NaN        NaN  ...
# 3                           NaN      NaN        NaN  ...
# 5                           NaN      NaN        NaN  ...
# 7                           NaN      NaN        NaN  ...
#
# name     Zoku Natsume Yuujinchou  Zoku Sayonara Zetsubou Sensei  Zombie-Loan  \
# user_id
# 1                            NaN                            NaN          NaN
# 2                            NaN                            NaN          NaN
# 3                            NaN                            NaN          7.0
# 5                            NaN                            7.0          NaN
# 7                            NaN                            NaN          NaN
#
# name     Zone of the Enders: Dolores, I  ef: A Tale of Melodies.  \
# user_id
# 1                                   NaN                      NaN
# 2                                   NaN                      NaN
# 3                                   NaN                      NaN
# 5                                   NaN                      NaN
# 7                                   NaN                      NaN
#
# name     ef: A Tale of Memories.  iDOLM@STER Xenoglossia  s.CRY.ed  xxxHOLiC  \
# user_id
# 1                            NaN                     NaN       NaN       NaN
# 2                            NaN                     NaN       NaN       NaN
# 3                            NaN                     NaN       NaN       NaN
# 5                            NaN                     NaN       NaN       2.0
# 7                            NaN                     NaN       NaN       NaN
#
# name     xxxHOLiC Kei
# user_id
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 5                 NaN
# 7                 NaN
#
# [5 rows x 1795 columns]

# %%
# 정규화
piv_norm = piv.apply(lambda x: (x - np.mean(x)) / (np.max(x) - np.min(x)), axis = 1)
# 평점을 매기지 않은 user column 제거
piv_norm.fillna(0, inplace = True)
piv_norm = piv_norm.T
piv_norm = piv_norm.loc[:, (piv_norm != 0).any(axis=0)]

# %%
# 희소 행렬 형태로 변환
piv_sparse = sp.sparse.csr_matrix(piv_norm.values)

# %%
#사용자 기반 유사도 행렬
user_similarity = cosine_similarity(piv_sparse.T)

# 아이템 기반 유사도 행렬
item_similarity = cosine_similarity(piv_sparse)

# %%
user_sim_df = pd.DataFrame(user_similarity, index = piv_norm.columns, columns = piv_norm.columns)
item_sim_df = pd.DataFrame(item_similarity, index = piv_norm.index, columns = piv_norm.index)

# %%
user_sim_df.head()
# Out:
# user_id     3         5         7         8         10            11     \
# user_id
# 3        1.000000  0.064821  0.167627  0.020365  0.125977  4.523309e-02
# 5        0.064821  1.000000  0.073114  0.016531  0.031570  5.464404e-03
# 7        0.167627  0.073114  1.000000 -0.013548  0.020401 -1.515745e-02
# 8        0.020365  0.016531 -0.013548  1.000000 -0.052705  1.892828e-02
# 10       0.125977  0.031570  0.020401 -0.052705  1.000000 -1.665335e-16
#
# user_id     12        14        16        17     ...     19989     19990  \
# user_id                                          ...
# 3        0.108629  0.005399  0.077388  0.248077  ...  0.101602  0.155584
# 5        0.094435  0.107404  0.007147  0.131081  ...  0.057388 -0.024971
# 7        0.061591  0.122852  0.048526  0.165479  ... -0.035113  0.052594
# 8        0.002786 -0.055035  0.000000  0.001329  ...  0.019713  0.000000
# 10       0.008811  0.044415  0.000000  0.071618  ...  0.190080  0.213980
#
# user_id     19992     19993     19994     19995     19996     19997     19998  \
# user_id
# 3        0.000000  0.074104  0.034628  0.083195 -0.052886 -0.016283  0.003794
# 5        0.011666  0.083377  0.117525  0.048341 -0.026435 -0.029484  0.040754
# 7       -0.064844  0.051428  0.068708  0.028304  0.000000  0.000000  0.046984
# 8        0.000000  0.034493  0.007308 -0.011986  0.000000  0.000000  0.046962
# 10       0.000000  0.000000  0.113134  0.140668  0.000000  0.000000  0.000000
#
# user_id     20000
# user_id
# 3       -0.020254
# 5       -0.005498
# 7        0.018660
# 8       -0.069722
# 10       0.000000
#
# [5 rows x 17053 columns]

# %%
# User ID를 입력했을 때, 입력된 User와 취향이 유사한 User 10명 반환하는 함수 
def top_users(user):
    
 if user not in piv_norm.columns:
      return('ID {} 유저의 정보가 없습니다.'.format(user))
   
 print('ID {}와 가장 유사한 유저는 다음과 같습니다.:\n'.format(user))
 sim_values = user_sim_df.sort_values(by=user, ascending=False).loc[:,user].tolist()[1:11]
 sim_users = user_sim_df.sort_values(by=user, ascending=False).index[1:11]
 zipped = zip(sim_users, sim_values,)
 for user, sim in zipped:
     print('ID {0}, 유사도: {1:.2f}'.format(user, sim))

# %%
top_users(20000)
# Out:
# ID 20000와 가장 유사한 유저는 다음과 같습니다.:
#
# ID 11085, 유사도: 0.86
# ID 2560, 유사도: 0.65
# ID 17099, 유사도: 0.52
# ID 16914, 유사도: 0.45
# ID 1368, 유사도: 0.44
# ID 6936, 유사도: 0.41
# ID 2069, 유사도: 0.39
# ID 5639, 유사도: 0.39
# ID 19042, 유사도: 0.37
# ID 12883, 유사도: 0.37

# %%
item_sim_df.head()
# Out:
# name                               .hack//Roots  .hack//Sign  \
# name
# .hack//Roots                           1.000000     0.208888
# .hack//Sign                            0.208888     1.000000
# .hack//Tasogare no Udewa Densetsu      0.294037     0.168604
# 009-1                                  0.013417     0.025281
# 07-Ghost                               0.035021     0.042555
#
# name                               .hack//Tasogare no Udewa Densetsu  \
# name
# .hack//Roots                                                0.294037
# .hack//Sign                                                 0.168604
# .hack//Tasogare no Udewa Densetsu                           1.000000
# 009-1                                                       0.037288
# 07-Ghost                                                    0.020993
#
# name                                  009-1  07-Ghost    11eyes  \
# name
# .hack//Roots                       0.013417  0.035021  0.042777
# .hack//Sign                        0.025281  0.042555  0.040025
# .hack//Tasogare no Udewa Densetsu  0.037288  0.020993  0.038395
# 009-1                              1.000000  0.006068  0.031984
# 07-Ghost                           0.006068  1.000000  0.086233
#
# name                               12-sai.: Chicchana Mune no Tokimeki  \
# name
# .hack//Roots                                                  0.017516
# .hack//Sign                                                   0.002459
# .hack//Tasogare no Udewa Densetsu                            -0.000361
# 009-1                                                         0.029974
# 07-Ghost                                                      0.009937
#
# name                               30-sai no Hoken Taiiku   91 Days  \
# name
# .hack//Roots                                     0.022737 -0.010055
# .hack//Sign                                      0.034466 -0.014535
# .hack//Tasogare no Udewa Densetsu                0.002783  0.000960
# 009-1                                            0.050457 -0.034925
# 07-Ghost                                         0.044858 -0.010993
#
# name                               A-Channel  ...  Zoku Natsume Yuujinchou  \
# name                                          ...
# .hack//Roots                        0.014429  ...                -0.052543
# .hack//Sign                         0.033941  ...                -0.031616
# .hack//Tasogare no Udewa Densetsu   0.016956  ...                -0.035796
# 009-1                               0.052102  ...                -0.003461
# 07-Ghost                            0.014321  ...                -0.060371
#
# name                               Zoku Sayonara Zetsubou Sensei  Zombie-Loan  \
# name
# .hack//Roots                                           -0.015453     0.010984
# .hack//Sign                                            -0.019560     0.035092
# .hack//Tasogare no Udewa Densetsu                      -0.023923     0.029486
# 009-1                                                   0.011822    -0.005609
# 07-Ghost                                               -0.012864     0.041818
#
# name                               Zone of the Enders: Dolores, I  \
# name
# .hack//Roots                                            -0.005756
# .hack//Sign                                              0.014673
# .hack//Tasogare no Udewa Densetsu                        0.019901
# 009-1                                                    0.003363
# 07-Ghost                                                 0.002020
#
# name                               ef: A Tale of Melodies.  \
# name
# .hack//Roots                                     -0.024250
# .hack//Sign                                      -0.023841
# .hack//Tasogare no Udewa Densetsu                -0.016840
# 009-1                                            -0.006517
# 07-Ghost                                         -0.026509
#
# name                               ef: A Tale of Memories.  \
# name
# .hack//Roots                                     -0.016565
# .hack//Sign                                      -0.006569
# .hack//Tasogare no Udewa Densetsu                -0.023182
# 009-1                                            -0.005316
# 07-Ghost                                         -0.025946
#
# name                               iDOLM@STER Xenoglossia  s.CRY.ed  xxxHOLiC  \
# name
# .hack//Roots                                     0.013604  0.021661 -0.026765
# .hack//Sign                                     -0.012319  0.007937 -0.020464
# .hack//Tasogare no Udewa Densetsu                0.001717  0.010111 -0.045788
# 009-1                                           -0.002141 -0.010789  0.013313
# 07-Ghost                                        -0.001227  0.022191 -0.017103
#
# name                               xxxHOLiC Kei
# name
# .hack//Roots                          -0.025869
# .hack//Sign                           -0.026013
# .hack//Tasogare no Udewa Densetsu     -0.033940
# 009-1                                  0.007863
# 07-Ghost                              -0.014243
#
# [5 rows x 1795 columns]

# %%
# 애니메이션 제목을 입력했을 때, 입력된 애니메이션과 비슷한 작품 10개 반환하는 함수
def top_items(anime):
  count = 1
  print('애니메이션 \'{}\'와 가장 유사한 애니메이션은 다음과 같습니다.:\n'.format(anime))
  for item in item_sim_df.sort_values(by = anime, ascending = False).index[1:11]:
    print('{}번 : {}'.format(count, item))
    count += 1

# %%
top_items('Naruto')
# Out:
# 애니메이션 'Naruto'와 가장 유사한 애니메이션은 다음과 같습니다.:
#
# 1번 : Bleach
# 2번 : Dragon Ball GT
# 3번 : Yu☆Gi☆Oh! Duel Monsters
# 4번 : Dragon Ball Z
# 5번 : Fairy Tail
# 6번 : Pokemon Advanced Generation
# 7번 : Ao no Exorcist
# 8번 : D.Gray-man
# 9번 : Highschool of the Dead
# 10번 : Dragon Ball
